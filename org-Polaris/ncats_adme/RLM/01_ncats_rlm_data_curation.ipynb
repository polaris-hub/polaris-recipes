# %% [markdown]
# Note: this notebook is set up to run with the env.yml containing the name 'polaris_datasets'

# %% [markdown]
# ## Background
# ADME@NCATS is a resource developed by NCATS to host in silico prediction models for various ADME (Absorption, Distribution, Metabolism and Excretion) properties. The resource serves as an important tool for the drug discovery community with potential uses in compound optimization and prioritization. The models were retrospectively validated on a subset of marketed drugs which resulted in very good accuracies.
#
# Data that were used for developing the models are made publicly accessible by depositing them into PubChem database. In some instances, when complete data cannot be made public, a subset of the data are deposited into PubChem. Links to the PubChem assays can be found in the individual model pages. The users are highly encouraged to use these data for development and validation of QSAR models.
#
# ## Assay Information
# Hepatic metabolic stability is a key pharmacokinetic parameter in drug discovery. Metabolic stability is usually assessed in microsomal fractions and only the best compounds progress in the drug discovery process. A high-throughput single time point substrate depletion method in rat liver microsomes (RLM) is employed at the National Center for Advancing Translational Sciences (NCATS) as a Tier 1 assay. Between 2012 and 2020, RLM stability (in vitro half-life) data was generated for ~24,000 compounds from more than 250 NCATS projects that cover a wide range of pharmacological targets and cellular pathways. Data for ~2500 compounds along with the global prediction models are publicly available.
#
# ![image.png](https://storage.googleapis.com/polaris-public/icons/icon_adme_ncats.jpg)
#
# Image is from [this paper](https://link.springer.com/article/10.1007/s00216-016-9929-6). Biologically active compounds can be transformed or destroyed by the action of enzymes in the liver. Microsomes are small membrane bubbles (vesicles) that come from a fragmented cell membrane, and can be used as a proxy for how well a drug survives a trip through the liver.
#
# ## Description of readout:
# - **PUBCHEM_ACTIVITY_OUTCOME**: Corresponds to the phenotype observed. For all compounds with phenotype "stable", PUBCHEM_ACTIVITY_OUTCOME is "active" (class = 1). For all compounds with phenotype "unstable", PUBCHEM_ACTIVITY_OUTCOME is "inactive" (class = 0).
# - **PHENOTYPE**: Based on the half-life observed. Compound is "stable" if half-life (t1/2) is more than 30 minutes (class = 1); "unstable" if t1/2 is less than 30 minutes (class = 0).
# - **HALF-LIFE**: Rat liver microsome stability (t1/2), in minutes. >30 minutes has been converted to 31.
#
# **Optimization objective**: A drug with high hepatic metabolic stability is often desirable as it can result in a more sustained therapeutic effect with lower dosing frequencies. However, excessive metabolic stability can lead to drug accumulation and potential toxicity. There may not be a universally applicable optimal range for hepatic metabolic stability, the goal is to achieve a balance that maximizes therapeutic benefit while minimizing adverse effects and maintaining an acceptable safety profile.
#
# In the context of this dataset, `stable` compounds are preferable.
#
# ## Data resource
#
# **Reference**: https://www.ncbi.nlm.nih.gov/pmc/articles/PMC7693334/
#
# **Raw data**: https://pubchem.ncbi.nlm.nih.gov/bioassay/1508591

# %%
# %load_ext autoreload
# %autoreload 2

import os
import sys
import pathlib

import pandas as pd
import datamol as dm

root = pathlib.Path("__file__").absolute().parents[3]
# set to recipe root directory
os.chdir(root)
sys.path.insert(0, str(root))

# %%
org = "polaris"
data_name = "ncats_adme/RLM"
dirname = dm.fs.join(root, f"org-{org}", data_name)
gcp_root = f"gs://polaris-public/polaris-recipes/org-{org}/{data_name}"

# %% [markdown]
# All datasets were downloaded directly from Pubchem on 2024-03-21 by following the PubChem Bioassay links on https://opendata.ncats.nih.gov/adme/data.

# %%
# Load the data
source_data_path = f"{gcp_root}/data/raw/AID_1508591_raw.parquet"
data = pd.read_parquet(source_data_path)

# %% [markdown]
# Rows 0 and 1 are metadata; we will keep them separate.

# %%
meta_start = 0  # Start row index
meta_end = 2  # End row index + 1
data_meta = data.iloc[meta_start:(meta_end), :].copy()  # Save the metadata rows
data = data.drop(labels=list(range(meta_start, meta_end)), axis=0).reset_index(
    drop=True
)  # Drop those rows from the main dataframe
data_meta
# Out:
#   PUBCHEM_RESULT_TAG  PUBCHEM_SID  PUBCHEM_CID PUBCHEM_EXT_DATASOURCE_SMILES  \
# 0        RESULT_TYPE          NaN          NaN                          None
# 1       RESULT_DESCR          NaN          NaN                          None
#
#   PUBCHEM_ACTIVITY_OUTCOME  PUBCHEM_ACTIVITY_SCORE  PUBCHEM_ACTIVITY_URL  \
# 0                     None                     NaN                   NaN
# 1                     None                     NaN                   NaN
#
#    PUBCHEM_ASSAYDATA_COMMENT  \
# 0                        NaN
# 1                        NaN
#
#                                            Phenotype  \
# 0                                             STRING
# 1  Indicates type of activity observed: Unstable ...
#
#                     Half-life (minutes)  \
# 0                                STRING
# 1  Rat liver microsome stability (T1/2)
#
#                                     Analysis Comment            Compound QC
# 0                                             STRING                 STRING
# 1  Annotation/notes on a particular compound's da...  Source of compound QC

# %% [markdown]
# Drop the metadata rows and keep only the smiles, ID and outcome rows. We'll also turn all columns to uppercase for consistency and rename columns.

# %%
# Keep only the SMILES, ID and outcome rows
columns_to_keep = [
    "PUBCHEM_SID",
    "PUBCHEM_EXT_DATASOURCE_SMILES",
    "PUBCHEM_ACTIVITY_OUTCOME",
    "Phenotype",
    "Half-life (minutes)",
]
data = data[columns_to_keep]
data.rename(columns={"PUBCHEM_EXT_DATASOURCE_SMILES": "SMILES"}, inplace=True)
# Rename all columns to uppercase
for col in data.columns:
    data.rename(columns={col: col.upper()}, inplace=True)
# Rename half-life (minutes) to half-life (we will specify minutes in the metadata)
data.rename(columns={"HALF-LIFE (MINUTES)": "HALF-LIFE"}, inplace=True)

# %% [markdown]
# ### Map values to digits and replace cutoffs
# Half-life is given in minutes but anything over 30 minutes was treated as '>30'. To help with machine readability, we will convert '>30' to 31.0. We will also convert Active/Inactive and Stable/Unstable to binary (1/0 respectively).

# %%
# Map active/inactive and stable/unstable to 1 and 0
data["PUBCHEM_ACTIVITY_OUTCOME"] = data["PUBCHEM_ACTIVITY_OUTCOME"].map(
    {"Active": 1.0, "Inactive": 0.0}
)
data["PHENOTYPE"] = data["PHENOTYPE"].map({"stable": 1.0, "unstable": 0.0})
# Replace >30 with 31 so it can be operated on
data["HALF-LIFE"].replace(">30", "31.0", inplace=True)
# Convert types after replacement
data["HALF-LIFE"] = data["HALF-LIFE"].astype(float)

# %%
data.describe(include='all')
# Out:
#          PUBCHEM_SID                                   SMILES  \
# count   2.531000e+03                                     2531
# unique           NaN                                     2529
# top              NaN  CN=C1CN=C(C2=C(N1)C=CC(=C2)Cl)C3=CC=CN3
# freq             NaN                                        2
# mean    1.728745e+08                                      NaN
# std     1.258060e+08                                      NaN
# min     8.437060e+05                                      NaN
# 25%     8.965011e+07                                      NaN
# 50%     1.610040e+08                                      NaN
# 75%     1.741614e+08                                      NaN
# max     3.870657e+08                                      NaN
#
#         PUBCHEM_ACTIVITY_OUTCOME    PHENOTYPE    HALF-LIFE
# count                2531.000000  2531.000000  2531.000000
# unique                       NaN          NaN          NaN
# top                          NaN          NaN          NaN
# freq                         NaN          NaN          NaN
# mean                    0.297906     0.297906    15.272651
# std                     0.457428     0.457428    11.989177
# min                     0.000000     0.000000     0.900000
# 25%                     0.000000     0.000000     3.500000
# 50%                     0.000000     0.000000    11.030000
# 75%                     1.000000     1.000000    31.000000
# max                     1.000000     1.000000    31.000000

# %% [markdown]
# ### Perform data curation with `auroris.curation` module
# The curation process includes:
# - assign unique identifier to molecules
# - detect the stereochemistry information of molecules.
# - inspect the potential outliers of bioactivity values
# - merge rows of replicated molecules
# - detect isomers which show the activity shifts
#
# Check out the curation module in [Auroris](https://github.com/polaris-hub/auroris).

# %% [markdown]
# ### Run preliminary curation for data inspection

# %%
# Define data column names
data_cols = [
    "PUBCHEM_ACTIVITY_OUTCOME",
    "PHENOTYPE",
    "HALF-LIFE",
]
mol_col = "SMILES"

# %%
# import key curation components from auroris
from auroris.curation import Curator
from auroris.curation.actions import MoleculeCuration, OutlierDetection, Deduplication, StereoIsomerACDetection, ContinuousDistributionVisualization

# Define the curation workflow
curator = Curator(
    data_path=source_data_path, 
    steps=[
        MoleculeCuration(input_column=mol_col, y_cols = data_cols),
        ContinuousDistributionVisualization(y_cols=data_cols),
        OutlierDetection(method="zscore", columns=data_cols, threshold = 3, use_modified_zscore=True),
        StereoIsomerACDetection(y_cols=data_cols, threshold = 3)
    ],
    parallelized_kwargs = { "n_jobs": -1 }
)

curator.to_json(f"{dirname}/inspection_config.json")

# %%
# Run the curation step defined as above
data_inspection, report = curator(data)
# Out:
# 2024-06-03 20:02:17.981 | INFO     | auroris.curation._curator:transform:106 - Performing step: mol_curation
# 2024-06-03 20:02:36.764 | INFO     | auroris.curation._curator:transform:106 - Performing step: distribution
# 2024-06-03 20:02:37.173 | INFO     | auroris.curation._curator:transform:106 - Performing step: outlier_detection
# 2024-06-03 20:02:37.418 | INFO     | auroris.curation._curator:transform:106 - Performing step: ac_stereoisomer

# %%
#  get the curation logger
from auroris.report.broadcaster import LoggerBroadcaster

broadcaster = LoggerBroadcaster(report)
broadcaster.broadcast()
# Out:
# ===== Curation Report =====
# Time: 2024-06-03 20:02:17
# Version: dev
# ===== mol_curation =====
# [LOG]: New column added: MOL_smiles
# [LOG]: New column added: MOL_molhash_id
# [LOG]: New column added: MOL_molhash_id_no_stereo
# [LOG]: New column added: MOL_num_stereoisomers
# [LOG]: New column added: MOL_num_undefined_stereoisomers
# [LOG]: New column added: MOL_num_defined_stereo_center
# [LOG]: New column added: MOL_num_undefined_stereo_center
# [LOG]: New column added: MOL_num_stereo_center
# [LOG]: New column added: MOL_undefined_E_D
# [LOG]: New column added: MOL_undefined_E/Z
# [LOG]: Default `ecfp` fingerprint is used to visualize the chemical space.
# [LOG]: Molecules with undefined stereocenter detected: 443.
# [IMG]: Dimensions 2400 x 1200
# [IMG]: Dimensions 1200 x 2400
# ===== distribution =====
# [IMG]: Dimensions 1200 x 600
# [IMG]: Dimensions 1200 x 600
# [IMG]: Dimensions 1200 x 600
# ===== outlier_detection =====
# [LOG]: New column added: OUTLIER_PUBCHEM_ACTIVITY_OUTCOME
# [LOG]: Found 0 potential outliers with respect to the PUBCHEM_ACTIVITY_OUTCOME column for review.
# [LOG]: New column added: OUTLIER_PHENOTYPE
# [LOG]: Found 0 potential outliers with respect to the PHENOTYPE column for review.
# [LOG]: New column added: OUTLIER_HALF-LIFE
# [LOG]: Found 0 potential outliers with respect to the HALF-LIFE column for review.
# [IMG]: Dimensions 1200 x 600
# [IMG]: Dimensions 1200 x 600
# [IMG]: Dimensions 1200 x 600
# ===== ac_stereoisomer =====
# [LOG]: New column added: AC_PUBCHEM_ACTIVITY_OUTCOME
# [LOG]: Found 2 activity cliffs among stereoisomers with respect to the PUBCHEM_ACTIVITY_OUTCOME column.
# [LOG]: The molecule index are : 213 ,880
# [LOG]: New column added: AC_PHENOTYPE
# [LOG]: Found 2 activity cliffs among stereoisomers with respect to the PHENOTYPE column.
# [LOG]: The molecule index are : 213 ,880
# [LOG]: New column added: AC_HALF-LIFE
# [LOG]: Found no activity cliffs among stereoisomers with respect to the HALF-LIFE column.
# [IMG]: Dimensions 600 x 300
# [IMG]: Dimensions 600 x 300
# ===== Curation Report END =====

# %%
# Generate an HTML report with embedded visualizations showcasing the data analysis.
from utils.auroris_utils import HTMLBroadcaster

# export report to local directory
broadcaster = HTMLBroadcaster(report, f"{dirname}/inspection_report")
report_path = broadcaster.broadcast()

# %%
# check the curated data
data_inspection.describe(include='all')
# Out:
#          PUBCHEM_SID                                   SMILES  \
# count   2.531000e+03                                     2531
# unique           NaN                                     2529
# top              NaN  CN=C1CN=C(C2=C(N1)C=CC(=C2)Cl)C3=CC=CN3
# freq             NaN                                        2
# mean    1.728745e+08                                      NaN
# std     1.258060e+08                                      NaN
# min     8.437060e+05                                      NaN
# 25%     8.965011e+07                                      NaN
# 50%     1.610040e+08                                      NaN
# 75%     1.741614e+08                                      NaN
# max     3.870657e+08                                      NaN
#
#         PUBCHEM_ACTIVITY_OUTCOME    PHENOTYPE    HALF-LIFE  \
# count                2531.000000  2531.000000  2531.000000
# unique                       NaN          NaN          NaN
# top                          NaN          NaN          NaN
# freq                         NaN          NaN          NaN
# mean                    0.297906     0.297906    15.272651
# std                     0.457428     0.457428    11.989177
# min                     0.000000     0.000000     0.900000
# 25%                     0.000000     0.000000     3.500000
# 50%                     0.000000     0.000000    11.030000
# 75%                     1.000000     1.000000    31.000000
# max                     1.000000     1.000000    31.000000
#
#                                  MOL_smiles  \
# count                                  2531
# unique                                 2529
# top     CN=C1CN=C(c2ccc[nH]2)c2cc(Cl)ccc2N1
# freq                                      2
# mean                                    NaN
# std                                     NaN
# min                                     NaN
# 25%                                     NaN
# 50%                                     NaN
# 75%                                     NaN
# max                                     NaN
#
#                                   MOL_molhash_id  \
# count                                       2531
# unique                                      2529
# top     bb4504061cfb356324aa64c00169e1899b0622dc
# freq                                           2
# mean                                         NaN
# std                                          NaN
# min                                          NaN
# 25%                                          NaN
# 50%                                          NaN
# 75%                                          NaN
# max                                          NaN
#
#                         MOL_molhash_id_no_stereo  MOL_num_stereoisomers  \
# count                                       2531            2531.000000
# unique                                      2529                    NaN
# top     ffd0d15b9fc35ea9be4baaa745606fecb913a336                    NaN
# freq                                           2                    NaN
# mean                                         NaN             242.725010
# std                                          NaN            6512.604689
# min                                          NaN               1.000000
# 25%                                          NaN               1.000000
# 50%                                          NaN               1.000000
# 75%                                          NaN               2.000000
# max                                          NaN          262144.000000
#
#         MOL_num_undefined_stereoisomers  ...  MOL_num_undefined_stereo_center  \
# count                       2531.000000  ...                      2531.000000
# unique                              NaN  ...                              NaN
# top                                 NaN  ...                              NaN
# freq                                NaN  ...                              NaN
# mean                           4.590281  ...                         0.211774
# std                          162.827079  ...                         0.583871
# min                            1.000000  ...                         0.000000
# 25%                            1.000000  ...                         0.000000
# 50%                            1.000000  ...                         0.000000
# 75%                            1.000000  ...                         0.000000
# max                         8192.000000  ...                        12.000000
#
#         MOL_num_stereo_center  MOL_undefined_E_D MOL_undefined_E/Z  \
# count             2531.000000               2531            2531.0
# unique                    NaN                  2               1.0
# top                       NaN              False               0.0
# freq                      NaN               2120            2531.0
# mean                 0.434216                NaN               NaN
# std                  1.240903                NaN               NaN
# min                  0.000000                NaN               NaN
# 25%                  0.000000                NaN               NaN
# 50%                  0.000000                NaN               NaN
# 75%                  0.000000                NaN               NaN
# max                 18.000000                NaN               NaN
#
#         OUTLIER_PUBCHEM_ACTIVITY_OUTCOME OUTLIER_PHENOTYPE OUTLIER_HALF-LIFE  \
# count                               2531              2531              2531
# unique                                 1                 1                 1
# top                                False             False             False
# freq                                2531              2531              2531
# mean                                 NaN               NaN               NaN
# std                                  NaN               NaN               NaN
# min                                  NaN               NaN               NaN
# 25%                                  NaN               NaN               NaN
# 50%                                  NaN               NaN               NaN
# 75%                                  NaN               NaN               NaN
# max                                  NaN               NaN               NaN
#
#        AC_PUBCHEM_ACTIVITY_OUTCOME AC_PHENOTYPE AC_HALF-LIFE
# count                         2531         2531         2531
# unique                           2            2            1
# top                          False        False        False
# freq                          2529         2529         2531
# mean                           NaN          NaN          NaN
# std                            NaN          NaN          NaN
# min                            NaN          NaN          NaN
# 25%                            NaN          NaN          NaN
# 50%                            NaN          NaN          NaN
# 75%                            NaN          NaN          NaN
# max                            NaN          NaN          NaN
#
# [11 rows x 21 columns]

# %% [markdown]
# #### The readout `HALF-LIFE` is capped by value 31 which limits the usefulness of the normality plot.

# %% [markdown]
# ![halflife](inspection_report/images/7-Outlier_detection_HALF-LIFE.png)

# %% [markdown]
# ### Check activity shift between stereoisomers

# %%
data_inspection.loc[[213, 880]]
# Out:
#      PUBCHEM_SID                                   SMILES  \
# 213  109967254.0  CN=C1CN=C(C2=C(N1)C=CC(=C2)Cl)C3=CC=CN3
# 880  109967257.0  CN=C1CN=C(C2=C(N1)C=CC(=C2)Cl)C3=CC=CN3
#
#      PUBCHEM_ACTIVITY_OUTCOME  PHENOTYPE  HALF-LIFE  \
# 213                       1.0        1.0      31.00
# 880                       0.0        0.0      22.99
#
#                               MOL_smiles  \
# 213  CN=C1CN=C(c2ccc[nH]2)c2cc(Cl)ccc2N1
# 880  CN=C1CN=C(c2ccc[nH]2)c2cc(Cl)ccc2N1
#
#                                MOL_molhash_id  \
# 213  bb4504061cfb356324aa64c00169e1899b0622dc
# 880  bb4504061cfb356324aa64c00169e1899b0622dc
#
#                      MOL_molhash_id_no_stereo  MOL_num_stereoisomers  \
# 213  ffd0d15b9fc35ea9be4baaa745606fecb913a336                      2
# 880  ffd0d15b9fc35ea9be4baaa745606fecb913a336                      2
#
#      MOL_num_undefined_stereoisomers  ...  MOL_num_undefined_stereo_center  \
# 213                                2  ...                                0
# 880                                2  ...                                0
#
#      MOL_num_stereo_center  MOL_undefined_E_D  MOL_undefined_E/Z  \
# 213                      0              False                  0
# 880                      0              False                  0
#
#     OUTLIER_PUBCHEM_ACTIVITY_OUTCOME  OUTLIER_PHENOTYPE  OUTLIER_HALF-LIFE  \
# 213                            False              False              False
# 880                            False              False              False
#
#      AC_PUBCHEM_ACTIVITY_OUTCOME AC_PHENOTYPE AC_HALF-LIFE
# 213                         True         True        False
# 880                         True         True        False
#
# [2 rows x 21 columns]

# %% [markdown]
# Two possible stereochemistry based activity shifts were detected in the dataset.
# Let's check the data in the dataset.

# %% [markdown]
# As we suspected, two samples with the same smiles but different SIDs are reported as being active or inactive. Looking at the molecules, they seem identical. We can't know which call is correct, so we should **remove** both. We'll do that below, after final curation.
#
# SID 109967254 is [ML223](https://pubchem.ncbi.nlm.nih.gov/substance/109967254) (left). SID 109967257 is [NCGC00188362-03](https://pubchem.ncbi.nlm.nih.gov/substance/109967257) (right) (we've flipped the second molecule across the x axis to get it in the same orientation as the one on the left).
#
# ![image-2.png](inspection_report/images/8-Activity_shifts_among_stereoisomers__PUBCHEM_ACTIVITY_OUTCOME.png)

# %% [markdown]
# ### Removing molecules as needed and re-run curation

# %%
# Make a fresh copy of the dataframe without the case where the curator has averaged scores.
data_to_curate = data.query(
    "SMILES != 'CN=C1CN=C(C2=C(N1)C=CC(=C2)Cl)C3=CC=CN3'"
).reset_index(drop=True)

# %% [markdown]
# ## Rerun data curation and export curated data for downstream tasks

# %%
# Define the final curation workflow
curator = Curator(
    source_data=source_data_path, 
    steps=[
        MoleculeCuration(input_column=mol_col, y_cols = data_cols),
        ContinuousDistributionVisualization(y_cols=data_cols),
        Deduplication(deduplicate_on=mol_col, y_cols=data_cols), # remove the replicated molecules
        OutlierDetection(method="zscore", columns=data_cols, threshold = 3, use_modified_zscore=True),
        StereoIsomerACDetection(y_cols=data_cols, threshold = 3)
    ],
    parallelized_kwargs = { "n_jobs": -1 }
)

# %%
# The final curation configuration is exported for reproducibility
path = f"{gcp_root}/data/curation/curation_config.json"
curator.to_json(path)

# %%
# Run the curation step defined as above
data_curated, report = curator(data_to_curate)
# Out:
# 2024-06-03 20:02:40.643 | INFO     | auroris.curation._curator:transform:106 - Performing step: mol_curation
# 2024-06-03 20:02:49.639 | INFO     | auroris.curation._curator:transform:106 - Performing step: distribution
# 2024-06-03 20:02:50.100 | INFO     | auroris.curation._curator:transform:106 - Performing step: deduplicate
# 2024-06-03 20:02:51.597 | INFO     | auroris.curation._curator:transform:106 - Performing step: outlier_detection
# 2024-06-03 20:02:51.742 | INFO     | auroris.curation._curator:transform:106 - Performing step: ac_stereoisomer

# %%
broadcaster = LoggerBroadcaster(report)
broadcaster.broadcast()
# Out:
# ===== Curation Report =====
# Time: 2024-06-03 20:02:40
# Version: dev
# ===== mol_curation =====
# [LOG]: New column added: MOL_smiles
# [LOG]: New column added: MOL_molhash_id
# [LOG]: New column added: MOL_molhash_id_no_stereo
# [LOG]: New column added: MOL_num_stereoisomers
# [LOG]: New column added: MOL_num_undefined_stereoisomers
# [LOG]: New column added: MOL_num_defined_stereo_center
# [LOG]: New column added: MOL_num_undefined_stereo_center
# [LOG]: New column added: MOL_num_stereo_center
# [LOG]: New column added: MOL_undefined_E_D
# [LOG]: New column added: MOL_undefined_E/Z
# [LOG]: Default `ecfp` fingerprint is used to visualize the chemical space.
# [LOG]: Molecules with undefined stereocenter detected: 443.
# [IMG]: Dimensions 2400 x 1200
# [IMG]: Dimensions 1200 x 2400
# ===== distribution =====
# [IMG]: Dimensions 1200 x 600
# [IMG]: Dimensions 1200 x 600
# [IMG]: Dimensions 1200 x 600
# ===== deduplicate =====
# [LOG]: Deduplication merged and removed 1 duplicated molecules from dataset
# ===== outlier_detection =====
# [LOG]: New column added: OUTLIER_PUBCHEM_ACTIVITY_OUTCOME
# [LOG]: Found 0 potential outliers with respect to the PUBCHEM_ACTIVITY_OUTCOME column for review.
# [LOG]: New column added: OUTLIER_PHENOTYPE
# [LOG]: Found 0 potential outliers with respect to the PHENOTYPE column for review.
# [LOG]: New column added: OUTLIER_HALF-LIFE
# [LOG]: Found 0 potential outliers with respect to the HALF-LIFE column for review.
# [IMG]: Dimensions 1200 x 600
# [IMG]: Dimensions 1200 x 600
# [IMG]: Dimensions 1200 x 600
# ===== ac_stereoisomer =====
# [LOG]: New column added: AC_PUBCHEM_ACTIVITY_OUTCOME
# [LOG]: Found no activity cliffs among stereoisomers with respect to the PUBCHEM_ACTIVITY_OUTCOME column.
# [LOG]: New column added: AC_PHENOTYPE
# [LOG]: Found no activity cliffs among stereoisomers with respect to the PHENOTYPE column.
# [LOG]: New column added: AC_HALF-LIFE
# [LOG]: Found no activity cliffs among stereoisomers with respect to the HALF-LIFE column.
# ===== Curation Report END =====

# %%
# Export report to polaris public directory on GCP
# The report is ready to reviewed in the HTML file.
broadcaster = HTMLBroadcaster(report, f"{gcp_root}/data/curation/report", embed_images=True)
broadcaster.broadcast()
# Out:
# 'gs://polaris-public/polaris-recipes/org-polaris/ncats_adme/RLM/data/curation/report/index.html'

# %% [markdown]
# ## Export the final curated data

# %%
fout = f"{gcp_root}/data/curation/{data_name}_curated.csv"
data_curated.reset_index(drop=True).to_csv(fout, index=False)

# %%
fout
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 fout
#
# NameError: name 'fout' is not defined

# %%
# Make a temporary directory to save the dataset
temp_dir = tempfile.TemporaryDirectory().name

save_dir = dm.fs.join(temp_dir, "dataset")

path = dataset.to_json(save_dir)

# Look at the save destination
fs = dm.fs.get_mapper(save_dir).fs
fs.ls(save_dir)
# Out:
# /Users/lu.zhu/miniconda3/envs/polaris_datasets/lib/python3.12/site-packages/pydantic/main.py:314: UserWarning: Pydantic serializer warnings:
#   Expected `url` but got `str` - serialized value may not be as expected
#   Expected `url` but got `str` - serialized value may not be as expected
#   return self.__pydantic_serializer__.to_python(
# ['/var/folders/_7/ffxc1f251dbb5msn977xl4sm0000gr/T/tmp8_vg7pfj/dataset/table.parquet',
#  '/var/folders/_7/ffxc1f251dbb5msn977xl4sm0000gr/T/tmp8_vg7pfj/dataset/dataset.json']

# %%
folder = "04_ADME_NCATS"
data_curated.to_parquet(
    f"gs://polaris-private/curated_datasets/{folder}/{dataset.name}_curated.parquet"
)  # Save just in case. Requires a data folder.

save_dir = f"gs://polaris-private/Datasets/{folder}/{dataset.name}"
dataset.to_json(save_dir)

save_dir = f"gs://polaris-public/Datasets/{folder}/{dataset.name}"
dataset.to_json(save_dir)

# dataset.upload_to_hub()
# Out:
# 'gs://polaris-public/Datasets/04_ADME_NCATS/ADME_NCATS_RLM_Stability/dataset.json'

# %%
d = Dataset.from_json('gs://polaris-public/Datasets/04_ADME_NCATS/ADME_NCATS_RLM_Stability/dataset.json')
d.license =  {"id": "CC-BY-4.0", "reference": "https://creativecommons.org/licenses/by/4.0/"}
d.upload_to_hub()
# Out:
# /Users/lu.zhu/miniconda3/envs/polaris_datasets/lib/python3.12/site-packages/pydantic/main.py:314: UserWarning: Pydantic serializer warnings:
#   Expected `url` but got `str` - serialized value may not be as expected
#   Expected `url` but got `str` - serialized value may not be as expected
#   return self.__pydantic_serializer__.to_python(
# ---------------------------------------------------------------------------
# ConnectError                              Traceback (most recent call last)
# File ~/miniconda3/envs/polaris_datasets/lib/python3.12/site-packages/httpx/_transports/default.py:69, in map_httpcore_exceptions()
#      68 try:
# ---> 69     yield
#      70 except Exception as exc:
#
# File ~/miniconda3/envs/polaris_datasets/lib/python3.12/site-packages/httpx/_transports/default.py:233, in HTTPTransport.handle_request(self, request)
#     232 with map_httpcore_exceptions():
# --> 233     resp = self._pool.handle_request(req)
#     235 assert isinstance(resp.stream, typing.Iterable)
#
# File ~/miniconda3/envs/polaris_datasets/lib/python3.12/site-packages/httpcore/_sync/connection_pool.py:216, in ConnectionPool.handle_request(self, request)
#     215     self._close_connections(closing)
# --> 216     raise exc from None
#     218 # Return the response. Note that in this case we still have to manage
#     219 # the point at which the response is closed.
#
# File ~/miniconda3/envs/polaris_datasets/lib/python3.12/site-packages/httpcore/_sync/connection_pool.py:196, in ConnectionPool.handle_request(self, request)
#     194 try:
#     195     # Send the request on the assigned connection.
# --> 196     response = connection.handle_request(
#     197         pool_request.request
#     198     )
#     199 except ConnectionNotAvailable:
#     200     # In some cases a connection may initially be available to
#     201     # handle a request, but then become unavailable.
#     202     #
#     203     # In this case we clear the connection and try again.
#
# File ~/miniconda3/envs/polaris_datasets/lib/python3.12/site-packages/httpcore/_sync/connection.py:99, in HTTPConnection.handle_request(self, request)
#      98     self._connect_failed = True
# ---> 99     raise exc
#     101 return self._connection.handle_request(request)
#
# File ~/miniconda3/envs/polaris_datasets/lib/python3.12/site-packages/httpcore/_sync/connection.py:76, in HTTPConnection.handle_request(self, request)
#      75 if self._connection is None:
# ---> 76     stream = self._connect(request)
#      78     ssl_object = stream.get_extra_info("ssl_object")
#
# File ~/miniconda3/envs/polaris_datasets/lib/python3.12/site-packages/httpcore/_sync/connection.py:154, in HTTPConnection._connect(self, request)
#     153 with Trace("start_tls", logger, request, kwargs) as trace:
# --> 154     stream = stream.start_tls(**kwargs)
#     155     trace.return_value = stream
#
# File ~/miniconda3/envs/polaris_datasets/lib/python3.12/site-packages/httpcore/_backends/sync.py:152, in SyncStream.start_tls(self, ssl_context, server_hostname, timeout)
#     148 exc_map: ExceptionMapping = {
#     149     socket.timeout: ConnectTimeout,
#     150     OSError: ConnectError,
#     151 }
# --> 152 with map_exceptions(exc_map):
#     153     try:
#
# File ~/miniconda3/envs/polaris_datasets/lib/python3.12/contextlib.py:158, in _GeneratorContextManager.__exit__(self, typ, value, traceback)
#     157 try:
# --> 158     self.gen.throw(value)
#     159 except StopIteration as exc:
#     160     # Suppress StopIteration *unless* it's the same exception that
#     161     # was passed to throw().  This prevents a StopIteration
#     162     # raised inside the "with" statement from being suppressed.
#
# File ~/miniconda3/envs/polaris_datasets/lib/python3.12/site-packages/httpcore/_exceptions.py:14, in map_exceptions(map)
#      13     if isinstance(exc, from_exc):
# ---> 14         raise to_exc(exc) from exc
#      15 raise
#
# ConnectError: [SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: self-signed certificate in certificate chain (_ssl.c:1000)
#
# The above exception was the direct cause of the following exception:
#
# ConnectError                              Traceback (most recent call last)
# File ~/Documents/Codebase/ValenceLab/polaris/polaris/hub/client.py:227, in PolarisHubClient.request(self, method, url, withhold_token, auth, **kwargs)
#     226 try:
# --> 227     response = super().request(method, url, withhold_token, auth, **kwargs)
#     228 except httpx.ConnectError as error:
#     229     # NOTE (cwognum): In the stack-trace, the more specific SSLCertVerificationError is raised.
#     230     #   We could use the traceback module to cactch this specific error, but that would be overkill here.
#
# File ~/miniconda3/envs/polaris_datasets/lib/python3.12/site-packages/authlib/integrations/httpx_client/oauth2_client.py:206, in OAuth2Client.request(self, method, url, withhold_token, auth, **kwargs)
#     204     auth = self.token_auth
# --> 206 return super().request(
#     207     method, url, auth=auth, **kwargs)
#
# File ~/miniconda3/envs/polaris_datasets/lib/python3.12/site-packages/httpx/_client.py:827, in Client.request(self, method, url, content, data, files, json, params, headers, cookies, auth, follow_redirects, timeout, extensions)
#     814 request = self.build_request(
#     815     method=method,
#     816     url=url,
#    (...)
#     825     extensions=extensions,
#     826 )
# --> 827 return self.send(request, auth=auth, follow_redirects=follow_redirects)
#
# File ~/miniconda3/envs/polaris_datasets/lib/python3.12/site-packages/httpx/_client.py:914, in Client.send(self, request, stream, auth, follow_redirects)
#     912 auth = self._build_request_auth(request, auth)
# --> 914 response = self._send_handling_auth(
#     915     request,
#     916     auth=auth,
#     917     follow_redirects=follow_redirects,
#     918     history=[],
#     919 )
#     920 try:
#
# File ~/miniconda3/envs/polaris_datasets/lib/python3.12/site-packages/httpx/_client.py:942, in Client._send_handling_auth(self, request, auth, follow_redirects, history)
#     941 while True:
# --> 942     response = self._send_handling_redirects(
#     943         request,
#     944         follow_redirects=follow_redirects,
#     945         history=history,
#     946     )
#     947     try:
#
# File ~/miniconda3/envs/polaris_datasets/lib/python3.12/site-packages/httpx/_client.py:979, in Client._send_handling_redirects(self, request, follow_redirects, history)
#     977     hook(request)
# --> 979 response = self._send_single_request(request)
#     980 try:
#
# File ~/miniconda3/envs/polaris_datasets/lib/python3.12/site-packages/httpx/_client.py:1015, in Client._send_single_request(self, request)
#    1014 with request_context(request=request):
# -> 1015     response = transport.handle_request(request)
#    1017 assert isinstance(response.stream, SyncByteStream)
#
# File ~/miniconda3/envs/polaris_datasets/lib/python3.12/site-packages/httpx/_transports/default.py:232, in HTTPTransport.handle_request(self, request)
#     220 req = httpcore.Request(
#     221     method=request.method,
#     222     url=httpcore.URL(
#    (...)
#     230     extensions=request.extensions,
#     231 )
# --> 232 with map_httpcore_exceptions():
#     233     resp = self._pool.handle_request(req)
#
# File ~/miniconda3/envs/polaris_datasets/lib/python3.12/contextlib.py:158, in _GeneratorContextManager.__exit__(self, typ, value, traceback)
#     157 try:
# --> 158     self.gen.throw(value)
#     159 except StopIteration as exc:
#     160     # Suppress StopIteration *unless* it's the same exception that
#     161     # was passed to throw().  This prevents a StopIteration
#     162     # raised inside the "with" statement from being suppressed.
#
# File ~/miniconda3/envs/polaris_datasets/lib/python3.12/site-packages/httpx/_transports/default.py:86, in map_httpcore_exceptions()
#      85 message = str(exc)
# ---> 86 raise mapped_exc(message) from exc
#
# ConnectError: [SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: self-signed certificate in certificate chain (_ssl.c:1000)
#
# The above exception was the direct cause of the following exception:
#
# SSLCertVerificationError                  Traceback (most recent call last)
# Cell In[48], line 3
#       1 d = Dataset.from_json('gs://polaris-public/Datasets/04_ADME_NCATS/ADME_NCATS_RLM_Stability/dataset.json')
#       2 d.license =  {"id": "CC-BY-4.0", "reference": "https://creativecommons.org/licenses/by/4.0/"}
# ----> 3 d.upload_to_hub()
#
# File ~/Documents/Codebase/ValenceLab/polaris/polaris/dataset/_dataset.py:312, in Dataset.upload_to_hub(self, access, owner)
#     303 def upload_to_hub(
#     304     self,
#     305     access: Optional[AccessType] = "private",
#     306     owner: Optional[Union[HubOwner, str]] = None,
#     307 ):
#     308     """
#     309     Very light, convenient wrapper around the
#     310     [`PolarisHubClient.upload_dataset`][polaris.hub.client.PolarisHubClient.upload_dataset] method.
#     311     """
# --> 312     self.client.upload_dataset(self, access=access, owner=owner)
#
# File ~/Documents/Codebase/ValenceLab/polaris/polaris/hub/client.py:583, in PolarisHubClient.upload_dataset(self, dataset, access, timeout, owner, if_exists)
#     580 # Step 1: Upload meta-data
#     581 # Instead of directly uploading the table, we announce to the hub that we intend to upload one.
#     582 url = f"/dataset/{dataset.artifact_id}"
# --> 583 response = self._base_request_to_hub(
#     584     url=url,
#     585     method="PUT",
#     586     json={
#     587         "tableContent": {
#     588             "size": parquet_size,
#     589             "fileType": "parquet",
#     590             "md5sum": parquet_md5,
#     591         },
#     592         "access": access,
#     593         **dataset_json,
#     594     },
#     595     timeout=timeout,
#     596 )
#     598 # Step 2: Upload the parquet file
#     599 # create an empty PUT request to get the table content URL from cloudflare
#     600 hub_response = self.request(
#     601     url=response["tableContent"]["url"],
#     602     method="PUT",
#    (...)
#     606     timeout=timeout,
#     607 )
#
# File ~/Documents/Codebase/ValenceLab/polaris/polaris/hub/client.py:143, in PolarisHubClient._base_request_to_hub(self, url, method, **kwargs)
#     141 def _base_request_to_hub(self, url: str, method: str, **kwargs):
#     142     """Utility function since most API methods follow the same pattern"""
# --> 143     response = self.request(url=url, method=method, **kwargs)
#     145     try:
#     146         response.raise_for_status()
#
# File ~/Documents/Codebase/ValenceLab/polaris/polaris/hub/client.py:232, in PolarisHubClient.request(self, method, url, withhold_token, auth, **kwargs)
#     228 except httpx.ConnectError as error:
#     229     # NOTE (cwognum): In the stack-trace, the more specific SSLCertVerificationError is raised.
#     230     #   We could use the traceback module to cactch this specific error, but that would be overkill here.
#     231     if _HTTPX_SSL_ERROR_CODE in str(error):
# --> 232         raise ssl.SSLCertVerificationError(
#     233             "We could not verify the SSL certificate. "
#     234             f"Please ensure the installed version ({certifi.__version__}) of the `certifi` package is the latest. "
#     235             "If you require the usage of a custom CA bundle, you can set the POLARIS_CA_BUNDLE "
#     236             "environment variable to the path of your CA bundle. For debugging, you can temporarily disable "
#     237             "SSL verification by setting the POLARIS_CA_BUNDLE environment variable to `false`."
#     238         ) from error
#     239     raise error
#     240 except (
#     241     MissingTokenError,
#     242     InvalidTokenError,
#     243     httpx.HTTPStatusError,
#     244     OAuthError,
#     245 ) as error:
#
# SSLCertVerificationError: ('We could not verify the SSL certificate. Please ensure the installed version (2024.02.02) of the `certifi` package is the latest. If you require the usage of a custom CA bundle, you can set the POLARIS_CA_BUNDLE environment variable to the path of your CA bundle. For debugging, you can temporarily disable SSL verification by setting the POLARIS_CA_BUNDLE environment variable to `false`.',)
