# %%
import pandas as pd

# %%
data = pd.read_table("/Users/lu.zhu/Downloads/tx3c00305_si_003.xlsx - test_set_Zimmerlin2011.csv", sep=',')

# %%
data
# Out:
#                                              Structure   kobs  \
# 0                     CCN(CC)CCNC(=O)c1ccc(cc1)NC(C)=O  0.005
# 1    COc1ccc2c(c1)C(CC(=O)OCC(O)=O)=C(C)N2C(=O)c3cc...  0.011
# 2                         CCCSc2ccc1NC(NC(=O)OC)=Nc1c2  0.008
# 3                      CC(CN(C)C)CN3c1ccccc1Sc2ccccc23  0.009
# 4               CC3=NN=C4CN=C(c1ccccc1)c2cc(Cl)ccc2N34  0.016
# ..                                                 ...    ...
# 363              NC2C=CN([C@H]1CC[C@@H](CO)O1)C(=O)N=2  0.006
# 364                   COc1cc(ccc1OC(F)F)C2C=CC(=O)NN=2  0.008
# 365  CC2=CN([C@H]1C[C@H](N=[N+]=[N-])[C@@H](CO)O1)C...  0.008
# 366                       CC(C2=Cc1ccccc1S2)N(O)C(N)=O  0.005
# 367     CN1CCN(CC1)C(=O)OC3c2nccnc2C(=O)N3c4ccc(Cl)cn4  0.009
#
#     Non-proprietary name
# 0             Acecainide
# 1             Acemetacin
# 2            Albendazole
# 3            Alimemazine
# 4             Alprazolam
# ..                   ...
# 363          Zalcitabine
# ...

# %%
data.to_parquet("gs://polaris-public/data/raw/novartis/test_set_Zimmerlin2011.parquet", index=False)

# %%
# data.to_parquet("gs://polaris-public/data/raw/novartis/surrogate_training_set_public.parquet", index=False)

# %%
data
# Out:
#                                              Structure   kobs  \
# 0                     CCN(CC)CCNC(=O)c1ccc(cc1)NC(C)=O  0.005
# 1    COc1ccc2c(c1)C(CC(=O)OCC(O)=O)=C(C)N2C(=O)c3cc...  0.011
# 2                         CCCSc2ccc1NC(NC(=O)OC)=Nc1c2  0.008
# 3                      CC(CN(C)C)CN3c1ccccc1Sc2ccccc23  0.009
# 4               CC3=NN=C4CN=C(c1ccccc1)c2cc(Cl)ccc2N34  0.016
# ..                                                 ...    ...
# 363              NC2C=CN([C@H]1CC[C@@H](CO)O1)C(=O)N=2  0.006
# 364                   COc1cc(ccc1OC(F)F)C2C=CC(=O)NN=2  0.008
# 365  CC2=CN([C@H]1C[C@H](N=[N+]=[N-])[C@@H](CO)O1)C...  0.008
# 366                       CC(C2=Cc1ccccc1S2)N(O)C(N)=O  0.005
# 367     CN1CCN(CC1)C(=O)OC3c2nccnc2C(=O)N3c4ccc(Cl)cn4  0.009
#
#     Non-proprietary name
# 0             Acecainide
# 1             Acemetacin
# 2            Albendazole
# 3            Alimemazine
# 4             Alprazolam
# ..                   ...
# 363          Zalcitabine
# ...
