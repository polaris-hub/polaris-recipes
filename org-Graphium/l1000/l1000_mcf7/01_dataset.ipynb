# %% [markdown]
# Note: this notebook is set up to run with the env.yml containing the name 'polaris_datasets'

# %% [markdown]
# # Dataset creation with [Polaris](https://github.com/polaris-hub/polaris)

# %%
# %load_ext autoreload
# %autoreload 2

import os
import sys
import pathlib

import pandas as pd
import datamol as dm

# polaris dataset
from polaris.dataset import Dataset, ColumnAnnotation

from polaris.utils.types import HubOwner


root = pathlib.Path("__file__").absolute().parents[3]
os.chdir(root)
sys.path.insert(0, str(root))
from utils.docs_utils import load_readme

# %%
# Get the owner and organization
org = "Graphium"
data_name = "l1000_mcf7"
dirname = dm.fs.join(root, f"org-{org}", data_name)
gcp_root = f"gs://polaris-public/polaris-recipes/org-{org}/{data_name}"

owner = HubOwner(slug=org.lower(), type="organization")
owner
# Out:
# HubOwner(slug='graphium', external_id=None, type='organization')

# %%
BENCHMARK_DIR = f"{gcp_root}/benchmarks"
DATASET_DIR = f"{gcp_root}/datasets"
FIGURE_DIR = f"{gcp_root}/figures"

# %% [markdown]
# ## Load existing data

# %%
PATH = f"{gcp_root}/data/raw/LINCS_L1000_MCF7_0-4.csv"
table = pd.read_csv(PATH)
table.columns
# Out:
# Index(['full_id', 'pert_id', 'cell_iname', 'SMILES', 'inchi_key',
#        'compound_aliases', 'geneID-10007', 'geneID-1001', 'geneID-10013',
#        'geneID-10038',
#        ...
#        'geneID-9918', 'geneID-9924', 'geneID-9926', 'geneID-9928',
#        'geneID-993', 'geneID-994', 'geneID-9943', 'geneID-9961', 'geneID-998',
#        'geneID-9988'],
#       dtype='object', length=984)

# %%
table.head(1)
# Out:
#                                       full_id        pert_id cell_iname  \
# 0  CRCGN004_MCF7_6H:BRD-K91960538-001-06-8:10  BRD-K91960538       MCF7
#
#           SMILES                    inchi_key compound_aliases  geneID-10007  \
# 0  CN(C)[N+][O-]  UMFJAHHVKNCGLG-UHFFFAOYSA-N              NaN             2
#
#    geneID-1001  geneID-10013  geneID-10038  ...  geneID-9918  geneID-9924  \
# 0            2             2             2  ...            2            2
#
#    geneID-9926  geneID-9928  geneID-993  geneID-994  geneID-9943  geneID-9961  \
# 0            2            2           2           2            2            2
#
#    geneID-998  geneID-9988
# 0           2            2
#
# [1 rows x 984 columns]

# %% [markdown]
# ### Below we specify the meta information of data columns

# %%
# Additional meta-data on the column level
annotations = {
    "full_id": ColumnAnnotation(description="full_id"),
    "pert_id": ColumnAnnotation(description="pert_id"),
    "cell_iname": ColumnAnnotation(description="Cell line name"),
    "SMILES": ColumnAnnotation(
        description="Molecule SMILES string", modality="molecule"
    ),
    "compound_aliases": ColumnAnnotation(
        description="Molecule identifier",
    ),
    **{
        col: ColumnAnnotation(description=col, modality="molecule")
        for col in table.columns
        if col.startswith("geneID")
    },
}

# %% [markdown]
# ### Define `Dataset` object

# %%
version = "v1"
dataset_name = f"{data_name}-{version}"

# %%
dataset = Dataset(
    # The table is the core data-structure required to construct a dataset
    table=table[annotations.keys()],
    # Additional meta-data on the dataset level.
    name=dataset_name,
    description="The LINCS L1000 is a database of high-throughput transcriptomics that screened more than 30,000 perturbations on a set of 978 landmark genes from human breast cancer cell line.",
    source="https://pubmed.ncbi.nlm.nih.gov/29195078/",
    annotations=annotations,
    tags=["LargeMix", "transcriptomics"],
    owner=owner,
    license="CC-BY-4.0",
    user_attributes={"year": "2017"},
    readme=load_readme(f"org-Graphium/l1000/{data_name}/readme.md"),
)

# %%
# save the dataset to GCP
SAVE_DIR = f"{DATASET_DIR}/{dataset_name}"
dataset_path = dataset.to_json(SAVE_DIR)
dataset_path
# Out:
# 2024-07-17 00:13:31.759 | INFO     | polaris._mixins:md5sum:27 - Computing the checksum. This can be slow for large datasets.
# 'gs://polaris-public/polaris-recipes/org-Graphium/l1000_mcf7/datasets/l1000_mcf7-v1/dataset.json'

# %%
from polaris.hub.client import PolarisHubClient

client = PolarisHubClient()
client.login()

client.upload_dataset(dataset=dataset, access="private", owner=owner)
# Out:
# 2024-07-17 00:14:38.773 | INFO     | polaris.hub.client:login:285 - You are already logged in to the Polaris Hub as  (lu@valencediscovery.com). Set `overwrite=True` to force re-authentication.
# 2024-07-17 00:14:45.091 | SUCCESS  | polaris.hub.client:upload_dataset:631 - Your dataset has been successfully uploaded to the Hub. View it here: https://polarishub.io/datasets/graphium/l1000_mcf7-v1
# {'id': '7C7RxULp5PcqQkiNRdoKK',
#  'createdAt': '2024-07-17T04:14:39.817Z',
#  'deletedAt': None,
#  'name': 'l1000-mcf7-v1',
#  'slug': 'l1000-mcf7-v1',
#  'description': 'The LINCS L1000 is a database of high-throughput transcriptomics that screened more than 30,000 perturbations on a set of 978 landmark genes from human breast cancer cell line.',
#  'tags': ['LargeMix', 'transcriptomics'],
#  'userAttributes': {'year': '2017'},
#  'access': 'private',
#  'isCertified': False,
#  'polarisVersion': 'dev',
#  'readme': '## Background\nZINC12K is a well-known dataset for researchers in GNN expressivity. We include it in our ToyMix since GNN expressivity is very important for performance on large-scale data. Hence, we hope that the performance on this task will correlate well with the performance when scaling.\n\n## Assay information\n\n\n## Description of readout:\n\n\n## Data resource\n\n',
#  'ownerId': 'zMTB7lQiiukqEmLQF7EjT',
#  'creatorId': 'NKnaHGybLqwSHcaMEHqfF',
#  'state': 'upload_pending',
#  'source': 'https://pubmed.ncbi.nlm.nih.gov/29195078/',
#  'curationReference': None,
#  'nRows': 11622,
#  'nColumns': 983,
#  'license': 'CC-BY-4.0',
#  'md5Sum': '5b640bbda93ad7cba01e231424d65922',
#  'annotations': {'SMILES': {'dtype': 'object',
#    'modality': 'MOLECULE',
#    'isPointer': False,
#    'description': 'Molecule SMILES string',
#    'userAttributes': {}},
#   'full_id': {'dtype': 'object',
#    'modality': 'UNKNOWN',
#    'isPointer': False,
#    'description': 'full_id',
#    'userAttributes': {}},
#   'pert_id': {'dtype': 'object',
#    'modality': 'UNKNOWN',
#    'isPointer': False,
#    'description': 'pert_id',
#    'userAttributes': {}},
#   'geneID-16': {'dtype': 'int64',
#    'modality': 'MOLECULE',
#    'isPointer': False,
#    'description': 'geneID-16',
#    'userAttributes': {}},
#   'geneID-23': {'dtype': 'int64',
#    'modality': 'MOLECULE',
#    'isPointer': False,
#    'description': 'geneID-23',
#    'userAttributes': {}},
#   'geneID-25': {'dtype': 'int64',
#    'modality': 'MOLECULE',
#    'isPointer': False,
#    'description': 'geneID-25',
#    'userAttributes': {}},
#   'geneID-30': {'dtype': 'int64',
#    'modality': 'MOLECULE',
#    'isPointer': False,
#    'description': 'geneID-30',
#    'userAttributes': {}},
#   'geneID-39': {'dtype': 'int64',
#    'modality': 'MOLECULE',
#    'isPointer': False,
#    'description': 'geneID-39',
#    'userAttributes': {}},
#   'geneID-47': {'dtype': 'int64',
#    'modality': 'MOLECULE',
#    'isPointer': False,
#    'description': 'geneID-47',
#    'userAttributes': {}},
#   'cell_iname': {'dtype': 'object',
#    'modality': 'UNKNOWN',
#    'isPointer': False,
#    'description': 'Cell line name',
#    'userAttributes': {}},
#   'geneID-102': {'dtype': 'int64',
#    'modality': 'MOLECULE',
#    'isPointer': False,
#    'description': 'geneID-102',
#    'userAttributes': {}},
#   'geneID-128': {'dtype': 'int64',
#    'modality': 'MOLECULE',
#    'isPointer': False,
#    'description': 'geneID-128',
#    'userAttributes': {}},
#   'geneID-142': {'dtype': 'int64',
#    'modality': 'MOLECULE',
#    'isPointer': False,
#    'description': 'geneID-142',
#    'userAttributes': {}},
#   'geneID-154': {'dtype': 'int64',
#    'modality': 'MOLECULE',
#    'isPointer': False,
#    'description': 'geneID-154',
#    'userAttributes': {}},
#   'geneID-178': {'dtype': 'int64',
#    'modality': 'MOLECULE',
#    'isPointer': False,
#    'description': 'geneID-178',
#    'userAttributes': {}},
#   'geneID-207': {'dtype': 'int64',
#    'modality': 'MOLECULE',
#    'isPointer': False,
#    'description': 'geneID-207',
#    'userAttributes': {}},
#   'geneID-211': {'dtype': 'int64',
#    'modality': 'MOLECULE',
#    'isPointer': False,
#    'description': 'geneID-211',
#    'userAttributes': {}},
#   'geneID-226': {'dtype': 'int64',
#    'modality': 'MOLECULE',
#    'isPointer': False,
#    'description': 'geneID-226',
#    'userAttributes': {}},
#   'geneID-230': {'dtype': 'int64',
#    'modality': 'MOLECULE',
#    'isPointer': False,
#    'description': 'geneID-230',
#    'userAttributes': {}},
#   'geneID-291': {'dtype': 'int64',
#    'modality': 'MOLECULE',
#    'isPointer': False,
#    'description': 'geneID-291',
#    'userAttributes': {}},
#   'geneID-310': {'dtype': 'int64',
#    'modality': 'MOLECULE',
#    'isPointer': False,
#    'description': 'geneID-310',
#    'userAttributes': {}},
#   'geneID-323': {'dtype': 'int64',
#    'modality': 'MOLECULE',
#    'isPointer': False,
#    'description': 'geneID-323',
#    'userAttributes': {}},
#   'geneID-329': {'dtype': 'int64',
#    'modality': 'MOLECULE',
#    'isPointer': False,
#    'description': 'geneID-329',
#    'userAttributes': {}},
#   'geneID-332': {'dtype': 'int64',
#    'modality': 'MOLECULE',
#    'isPointer': False,
#    'description': 'geneID-332',
#    'userAttributes': {}},
#   'geneID-348': {'dtype': 'int64',
#    'modality': 'MOLECULE',
#    'isPointer': False,
#    'description': 'geneID-348',
#    'userAttributes': {}},
#   'geneID-351': {'dtype': 'int64',
#    'modality': 'MOLECULE',
#    'isPointer': False,
#    'description': 'geneID-351',
#    'userAttributes': {}},
#   'geneID-355': {'dtype': 'int64',
#    'modality': 'MOLECULE',
#    'isPointer': False,
#    'description': 'geneID-355',
#    'userAttributes': {}},
#   'geneID-387': {'dtype': 'int64',
#    'modality': 'MOLECULE',
#    'isPointer': False,
#    'description': 'geneID-387',
#    'userAttributes': {}},
#   'geneID-392': {'dtype': 'int64',
#    'modality': 'MOLECULE',
#    'isPointer': False,
#    'description': 'geneID-392',
#    'userAttributes': {}},
#   'geneID-427': {'dtype': 'int64',
#    'modality': 'MOLECULE',
#    'isPointer': False,
#    'description': 'geneID-427',
#    'userAttributes': {}},
#   'geneID-466': {'dtype': 'int64',
#    'modality': 'MOLECULE',
#    'isPointer': False,
#    'description': 'geneID-466',
#    'userAttributes': {}},
#   'geneID-481': {'dtype': 'int64',
#    'modality': 'MOLECULE',
#    'isPointer': False,
#    'description': 'geneID-481',
#    'userAttributes': {}},
#   'geneID-501': {'dtype': 'int64',
#    'modality': 'MOLECULE',
#    'isPointer': False,
#    'description': 'geneID-501',
#    'userAttributes': {}},
#   'geneID-533': {'dtype': 'int64',
#    'modality': 'MOLECULE',
#    'isPointer': False,
#    'description': 'geneID-533',
#    'userAttributes': {}},
#   'geneID-572': {'dtype': 'int64',
#    'modality': 'MOLECULE',
#    'isPointer': False,
#    'description': 'geneID-572',
#    'userAttributes': {}},
#   'geneID-581': {'dtype': 'int64',
#    'modality': 'MOLECULE',
#    'isPointer': False,
#    'description': 'geneID-581',
#    'userAttributes': {}},
#   'geneID-595': {'dtype': 'int64',
#    'modality': 'MOLECULE',
#    'isPointer': False,
#    'description': 'geneID-595',
#    'userAttributes': {}},
#   'geneID-596': {'dtype': 'int64',
#    'modality': 'MOLECULE',
#    'isPointer': False,
#    'description': 'geneID-596',
#    'userAttributes': {}},
#   'geneID-622': {'dtype': 'int64',
#    'modality': 'MOLECULE',
#    'isPointer': False,
#    'description': 'geneID-622',
#    'userAttributes': {}},
#   'geneID-637': {'dtype': 'int64',
#    'modality': 'MOLECULE',
#    'isPointer': False,
#    'description': 'geneID-637',
#    'userAttributes': {}},
#   'geneID-642': {'dtype': 'int64',
#    'modality': 'MOLECULE',
#    'isPointer': False,
#    'description': 'geneID-642',
#    'userAttributes': {}},
#   'geneID-644': {'dtype': 'int64',
#    'modality': 'MOLECULE',
#    'isPointer': False,
#    'description': 'geneID-644',
#    'userAttributes': {}},
#   'geneID-652': {'dtype': 'int64',
#    'modality': 'MOLECULE',
#    'isPointer': False,
#    'description': 'geneID-652',
#    'userAttributes': {}},
#   'geneID-664': {'dtype': 'int64',
#    'modality': 'MOLECULE',
#    'isPointer': False,
#    'description': 'geneID-664',
#    'userAttributes': {}},
#   'geneID-665': {'dtype': 'int64',
#    'modality': 'MOLECULE',
#    'isPointer': False,
#    'description': 'geneID-665',
#    'userAttributes': {}},
#   'geneID-670': {'dtype': 'int64',
#    'modality': 'MOLECULE',
#    'isPointer': False,
#    'description': 'geneID-670',
#    'userAttributes': {}},
#   'geneID-672': {'dtype': 'int64',
#    'modality': 'MOLECULE',
#    'isPointer': False,
#    'description': 'geneID-672',
#    'userAttributes': {}},
#   'geneID-695': {'dtype': 'int64',
#    'modality': 'MOLECULE',
#    'isPointer': False,
#    'description': 'geneID-695',
#    'userAttributes': {}},
#   'geneID-701': {'dtype': 'int64',
#    'modality': 'MOLECULE',
#    'isPointer': False,
#    'description': 'geneID-701',
#    'userAttributes': {}},
#   'geneID-727': {'dtype': 'int64',
#    'modality': 'MOLECULE',
#    'isPointer': False,
#    'description': 'geneID-727',
#    'userAttributes': {}},
#   'geneID-780': {'dtype': 'int64',
#    'modality': 'MOLECULE',
#    'isPointer': False,
#    'description': 'geneID-780',
#    'userAttributes': {}},
#   'geneID-808': {'dtype': 'int64',
#    'modality': 'MOLECULE',
#    'isPointer': False,
#    'description': 'geneID-808',
#    'userAttributes': {}},
#   'geneID-813': {'dtype': 'int64',
#    'modality': 'MOLECULE',
#    'isPointer': False,
#    'description': 'geneID-813',
#    'userAttributes': {}},
#   'geneID-823': {'dtype': 'int64',
#    'modality': 'MOLECULE',
#    'isPointer': False,
#    'description': 'geneID-823',
#    'userAttributes': {}},
#   'geneID-831': {'dtype': 'int64',
#    'modality': 'MOLECULE',
#    'isPointer': False,
#    'description': 'geneID-831',
#    'userAttributes': {}},
#   'geneID-835': {'dtype': 'int64',
#    'modality': 'MOLECULE',
#    'isPointer': False,
#    'description': 'geneID-835',
#    'userAttributes': {}},
#   'geneID-836': {'dtype': 'int64',
#    'modality': 'MOLECULE',
#    'isPointer': False,
#    'description': 'geneID-836',
#    'userAttributes': {}},
#   'geneID-840': {'dtype': 'int64',
#    'modality': 'MOLECULE',
#    'isPointer': False,
#    'description': 'geneID-840',
#    'userAttributes': {}},
#   'geneID-843': {'dtype': 'int64',
#    'modality': 'MOLECULE',
#    'isPointer': False,
#    'description': 'geneID-843',
#    'userAttributes': {}},
#   'geneID-847': {'dtype': 'int64',
#    'modality': 'MOLECULE',
#    'isPointer': False,
#    'description': 'geneID-847',
#    'userAttributes': {}},
#   'geneID-868': {'dtype': 'int64',
#    'modality': 'MOLECULE',
#    'isPointer': False,
#    'description': 'geneID-868',
#    'userAttributes': {}},
#   'geneID-873': {'dtype': 'int64',
#    'modality': 'MOLECULE',
#    'isPointer': False,
#    'description': 'geneID-873',
#    'userAttributes': {}},
#   'geneID-874': {'dtype': 'int64',
#    'modality': 'MOLECULE',
#    'isPointer': False,
#    'description': 'geneID-874',
#    'userAttributes': {}},
#   'geneID-890': {'dtype': 'int64',
#    'modality': 'MOLECULE',
#    'isPointer': False,
#    'description': 'geneID-890',
#    'userAttributes': {}},
#   'geneID-891': {'dtype': 'int64',
#    'modality': 'MOLECULE',
#    'isPointer': False,
#    'description': 'geneID-891',
#    'userAttributes': {}},
#   'geneID-896': {'dtype': 'int64',
#    'modality': 'MOLECULE',
#    'isPointer': False,
#    'description': 'geneID-896',
#    'userAttributes': {}},
#   'geneID-899': {'dtype': 'int64',
#    'modality': 'MOLECULE',
#    'isPointer': False,
#    'description': 'geneID-899',
#    'userAttributes': {}},
#   'geneID-902': {'dtype': 'int64',
#    'modality': 'MOLECULE',
#    'isPointer': False,
#    'description': 'geneID-902',
#    'userAttributes': {}},
#   'geneID-949': {'dtype': 'int64',
#    'modality': 'MOLECULE',
#    'isPointer': False,
#    'description': 'geneID-949',
#    'userAttributes': {}},
#   'geneID-958': {'dtype': 'int64',
#    'modality': 'MOLECULE',
#    'isPointer': False,
#    'description': 'geneID-958',
#    'userAttributes': {}},
#   'geneID-960': {'dtype': 'int64',
#    'modality': 'MOLECULE',
#    'isPointer': False,
#    'description': 'geneID-960',
#    'userAttributes': {}},
#   'geneID-965': {'dtype': 'int64',
#    'modality': 'MOLECULE',
#    'isPointer': False,
#    'description': 'geneID-965',
#    'userAttributes': {}},
#   'geneID-976': {'dtype': 'int64',
#    'modality': 'MOLECULE',
#    'isPointer': False,
#    'description': 'geneID-976',
#    'userAttributes': {}},
#   'geneID-983': {'dtype': 'int64',
#    'modality': 'MOLECULE',
#    'isPointer': False,
#    'description': 'geneID-983',
#    'userAttributes': {}},
#   'geneID-991': {'dtype': 'int64',
#    'modality': 'MOLECULE',
#    'isPointer': False,
#    'description': 'geneID-991',
#    'userAttributes': {}},
#   'geneID-993': {'dtype': 'int64',
#    'modality': 'MOLECULE',
#    'isPointer': False,
#    'description': 'geneID-993',
#    'userAttributes': {}},
#   'geneID-994': {'dtype': 'int64',
#    'modality': 'MOLECULE',
#    'isPointer': False,
#    'description': 'geneID-994',
#    'userAttributes': {}},
#   'geneID-998': {'dtype': 'int64',
#    'modality': 'MOLECULE',
#    'isPointer': False,
#    'description': 'geneID-998',
#    'userAttributes': {}},
#   'geneID-1001': {'dtype': 'int64',
#    'modality': 'MOLECULE',
#    'isPointer': False,
#    'description': 'geneID-1001',
#    'userAttributes': {}},
#   'geneID-1017': {'dtype': 'int64',
#    'modality': 'MOLECULE',
#    'isPointer': False,
#    'description': 'geneID-1017',
#    'userAttributes': {}},
#   'geneID-1019': {'dtype': 'int64',
#    'modality': 'MOLECULE',
#    'isPointer': False,
#    'description': 'geneID-1019',
#    'userAttributes': {}},
#   'geneID-1021': {'dtype': 'int64',
#    'modality': 'MOLECULE',
#    'isPointer': False,
#    'description': 'geneID-1021',
#    'userAttributes': {}},
#   'geneID-1022': {'dtype': 'int64',
#    'modality': 'MOLECULE',
#    'isPointer': False,
#    'description': 'geneID-1022',
#    'userAttributes': {}},
#   'geneID-1026': {'dtype': 'int64',
#    'modality': 'MOLECULE',
#    'isPointer': False,
#    'description': 'geneID-1026',
#    'userAttributes': {}},
#   'geneID-1027': {'dtype': 'int64',
#    'modality': 'MOLECULE',
#    'isPointer': False,
#    'description': 'geneID-1027',
#    'userAttributes': {}},
#   'geneID-1029': {'dtype': 'int64',
#    'modality': 'MOLECULE',
#    'isPointer': False,
#    'description': 'geneID-1029',
#    'userAttributes': {}},
#   'geneID-1050': {'dtype': 'int64',
#    'modality': 'MOLECULE',
#    'isPointer': False,
#    'description': 'geneID-1050',
#    'userAttributes': {}},
#   'geneID-1052': {'dtype': 'int64',
#    'modality': 'MOLECULE',
#    'isPointer': False,
#    'description': 'geneID-1052',
#    'userAttributes': {}},
#   'geneID-1062': {'dtype': 'int64',
#    'modality': 'MOLECULE',
#    'isPointer': False,
#    'description': 'geneID-1062',
#    'userAttributes': {}},
#   'geneID-1070': {'dtype': 'int64',
#    'modality': 'MOLECULE',
#    'isPointer': False,
#    'description': 'geneID-1070',
#    'userAttributes': {}},
#   'geneID-1111': {'dtype': 'int64',
#    'modality': 'MOLECULE',
#    'isPointer': False,
#    'description': 'geneID-1111',
#    'userAttributes': {}},
#   'geneID-1123': {'dtype': 'int64',
#    'modality': 'MOLECULE',
#    'isPointer': False,
#    'description': 'geneID-1123',
#    'userAttributes': {}},
#   'geneID-1153': {'dtype': 'int64',
#    'modality': 'MOLECULE',
#    'isPointer': False,
#    'description': 'geneID-1153',
#    'userAttributes': {}},
#   'geneID-1212': {'dtype': 'int64',
#    'modality': 'MOLECULE',
#    'isPointer': False,
#    'description': 'geneID-1212',
#    'userAttributes': {}},
#   'geneID-1213': {'dtype': 'int64',
#    'modality': 'MOLECULE',
#    'isPointer': False,
#    'description': 'geneID-1213',
#    'userAttributes': {}},
#   'geneID-1277': {'dtype': 'int64',
#    'modality': 'MOLECULE',
#    'isPointer': False,
#    'description': 'geneID-1277',
#    'userAttributes': {}},
#   'geneID-1282': {'dtype': 'int64',
#    'modality': 'MOLECULE',
#    'isPointer': False,
#    'description': 'geneID-1282',
#    'userAttributes': {}},
#   'geneID-1385': {'dtype': 'int64',
#    'modality': 'MOLECULE',
#    'isPointer': False,
#    'description': 'geneID-1385',
#    'userAttributes': {}},
#   'geneID-1398': {'dtype': 'int64',
#    'modality': 'MOLECULE',
#    'isPointer': False,
#    'description': 'geneID-1398',
#    'userAttributes': {}},
#   'geneID-1399': {'dtype': 'int64',
#    'modality': 'MOLECULE',
#    'isPointer': False,
#    'description': 'geneID-1399',
#    'userAttributes': {}},
#   'geneID-1429': {'dtype': 'int64',
#    'modality': 'MOLECULE',
#    'isPointer': False,
#    'description': 'geneID-1429',
#    'userAttributes': {}},
#   'geneID-1445': {'dtype': 'int64',
#    'modality': 'MOLECULE',
#    'isPointer': False,
#    'description': 'geneID-1445',
#    'userAttributes': {}},
#   'geneID-1452': {'dtype': 'int64',
#    'modality': 'MOLECULE',
#    'isPointer': False,
#    'description': 'geneID-1452',
#    'userAttributes': {}},
#   'geneID-1454': {'dtype': 'int64',
#    'modality': 'MOLECULE',
#    'isPointer': False,
#    'description': 'geneID-1454',
#    'userAttributes': {}},
#   'geneID-1459': {'dtype': 'int64',
#    'modality': 'MOLECULE',
#    'isPointer': False,
#    'description': 'geneID-1459',
#    'userAttributes': {}},
#   'geneID-1465': {'dtype': 'int64',
#    'modality': 'MOLECULE',
#    'isPointer': False,
#    'description': 'geneID-1465',
#    'userAttributes': {}},
#   'geneID-1500': {'dtype': 'int64',
#    'modality': 'MOLECULE',
#    'isPointer': False,
#    'description': 'geneID-1500',
#    'userAttributes': {}},
#   'geneID-1509': {'dtype': 'int64',
#    'modality': 'MOLECULE',
#    'isPointer': False,
#    'description': 'geneID-1509',
#    'userAttributes': {}},
#   'geneID-1514': {'dtype': 'int64',
#    'modality': 'MOLECULE',
#    'isPointer': False,
#    'description': 'geneID-1514',
#    'userAttributes': {}},
#   'geneID-1534': {'dtype': 'int64',
#    'modality': 'MOLECULE',
#    'isPointer': False,
#    'description': 'geneID-1534',
#    'userAttributes': {}},
#   'geneID-1605': {'dtype': 'int64',
#    'modality': 'MOLECULE',
#    'isPointer': False,
#    'description': 'geneID-1605',
#    'userAttributes': {}},
#   'geneID-1616': {'dtype': 'int64',
#    'modality': 'MOLECULE',
#    'isPointer': False,
#    'description': 'geneID-1616',
#    'userAttributes': {}},
#   'geneID-1633': {'dtype': 'int64',
#    'modality': 'MOLECULE',
#    'isPointer': False,
#    'description': 'geneID-1633',
#    'userAttributes': {}},
#   'geneID-1635': {'dtype': 'int64',
#    'modality': 'MOLECULE',
#    'isPointer': False,
#    'description': 'geneID-1635',
#    'userAttributes': {}},
#   'geneID-1643': {'dtype': 'int64',
#    'modality': 'MOLECULE',
#    'isPointer': False,
#    'description': 'geneID-1643',
#    'userAttributes': {}},
#   'geneID-1647': {'dtype': 'int64',
#    'modality': 'MOLECULE',
#    'isPointer': False,
#    'description': 'geneID-1647',
#    'userAttributes': {}},
#   'geneID-1662': {'dtype': 'int64',
#    'modality': 'MOLECULE',
#    'isPointer': False,
#    'description': 'geneID-1662',
#    'userAttributes': {}},
#   'geneID-1666': {'dtype': 'int64',
#    'modality': 'MOLECULE',
#    'isPointer': False,
#    'description': 'geneID-1666',
#    'userAttributes': {}},
#   'geneID-1676': {'dtype': 'int64',
#    'modality': 'MOLECULE',
#    'isPointer': False,
#    'description': 'geneID-
{'dtype': 'int64',
#    'modality': 'MOLECULE',
#    'isPointer': False,
#    'description': 'geneID-55748',
#    'userAttributes': {}},
#   'geneID-55793': {'dtype': 'int64',
#    'modality': 'MOLECULE',
#    'isPointer': False,
#    'description': 'geneID-55793',
#    'userAttributes': {}},
#   'geneID-55818': {'dtype': 'int64',
#    'modality': 'MOLECULE',
#    'isPointer': False,
#    'description': 'geneID-55818',
#    'userAttributes': {}},
#   'geneID-55825': {'dtype': 'int64',
#    'modality': 'MOLECULE',
#    'isPointer': False,
#    'description': 'geneID-55825',
#    'userAttributes': {}},
#   'geneID-55837': {'dtype': 'int64',
#    'modality': 'MOLECULE',
#    'isPointer': False,
#    'description': 'geneID-55837',
#    'userAttributes': {}},
#   'geneID-55847': {'dtype': 'int64',
#    'modality': 'MOLECULE',
#    'isPointer': False,
#    'description': 'geneID-55847',
#    'userAttributes': {}},
#   'geneID-55893': {'dtype': 'int64',
#    'modality': 'MOLECULE',
#    'isPointer': False,
#    'description': 'geneID-55893',
#    'userAttributes': {}},
#   'geneID-55958': {'dtype': 'int64',
#    'modality': 'MOLECULE',
#    'isPointer': False,
#    'description': 'geneID-55958',
#    'userAttributes': {}},
#   'geneID-56654': {'dtype': 'int64',
#    'modality': 'MOLECULE',
#    'isPointer': False,
#    'description': 'geneID-56654',
#    'userAttributes': {}},
#   'geneID-56889': {'dtype': 'int64',
#    'modality': 'MOLECULE',
#    'isPointer': False,
#    'description': 'geneID-56889',
#    'userAttributes': {}},
#   'geneID-56924': {'dtype': 'int64',
#    'modality': 'MOLECULE',
#    'isPointer': False,
#    'description': 'geneID-56924',
#    'userAttributes': {}},
#   'geneID-56940': {'dtype': 'int64',
#    'modality': 'MOLECULE',
#    'isPointer': False,
#    'description': 'geneID-56940',
#    'userAttributes': {}},
#   'geneID-56997': {'dtype': 'int64',
#    'modality': 'MOLECULE',
#    'isPointer': False,
#    'description': 'geneID-56997',
#    'userAttributes': {}},
#   'geneID-57019': {'dtype': 'int64',
#    'modality': 'MOLECULE',
#    'isPointer': False,
#    'description': 'geneID-57019',
#    'userAttributes': {}},
#   'geneID-57048': {'dtype': 'int64',
#    'modality': 'MOLECULE',
#    'isPointer': False,
#    'description': 'geneID-57048',
#    'userAttributes': {}},
#   'geneID-57147': {'dtype': 'int64',
#    'modality': 'MOLECULE',
#    'isPointer': False,
#    'description': 'geneID-57147',
#    'userAttributes': {}},
#   'geneID-57149': {'dtype': 'int64',
#    'modality': 'MOLECULE',
#    'isPointer': False,
#    'description': 'geneID-57149',
#    'userAttributes': {}},
#   'geneID-57178': {'dtype': 'int64',
#    'modality': 'MOLECULE',
#    'isPointer': False,
#    'description': 'geneID-57178',
#    'userAttributes': {}},
#   'geneID-57192': {'dtype': 'int64',
#    'modality': 'MOLECULE',
#    'isPointer': False,
#    'description': 'geneID-57192',
#    'userAttributes': {}},
#   'geneID-57215': {'dtype': 'int64',
#    'modality': 'MOLECULE',
#    'isPointer': False,
#    'description': 'geneID-57215',
#    'userAttributes': {}},
#   'geneID-57406': {'dtype': 'int64',
#    'modality': 'MOLECULE',
#    'isPointer': False,
#    'description': 'geneID-57406',
#    'userAttributes': {}},
#   'geneID-57761': {'dtype': 'int64',
#    'modality': 'MOLECULE',
#    'isPointer': False,
#    'description': 'geneID-57761',
#    'userAttributes': {}},
#   'geneID-57804': {'dtype': 'int64',
#    'modality': 'MOLECULE',
#    'isPointer': False,
#    'description': 'geneID-57804',
#    'userAttributes': {}},
#   'geneID-58472': {'dtype': 'int64',
#    'modality': 'MOLECULE',
#    'isPointer': False,
#    'description': 'geneID-58472',
#    'userAttributes': {}},
#   'geneID-58478': {'dtype': 'int64',
#    'modality': 'MOLECULE',
#    'isPointer': False,
#    'description': 'geneID-58478',
#    'userAttributes': {}},
#   'geneID-58497': {'dtype': 'int64',
#    'modality': 'MOLECULE',
#    'isPointer': False,
#    'description': 'geneID-58497',
#    'userAttributes': {}},
#   'geneID-58533': {'dtype': 'int64',
#    'modality': 'MOLECULE',
#    'isPointer': False,
#    'description': 'geneID-58533',
#    'userAttributes': {}},
#   'geneID-60493': {'dtype': 'int64',
#    'modality': 'MOLECULE',
#    'isPointer': False,
#    'description': 'geneID-60493',
#    'userAttributes': {}},
#   'geneID-60528': {'dtype': 'int64',
#    'modality': 'MOLECULE',
#    'isPointer': False,
#    'description': 'geneID-60528',
#    'userAttributes': {}},
#   'geneID-63874': {'dtype': 'int64',
#    'modality': 'MOLECULE',
#    'isPointer': False,
#    'description': 'geneID-63874',
#    'userAttributes': {}},
#   'geneID-63933': {'dtype': 'int64',
#    'modality': 'MOLECULE',
#    'isPointer': False,
#    'description': 'geneID-63933',
#    'userAttributes': {}},
#   'geneID-64080': {'dtype': 'int64',
#    'modality': 'MOLECULE',
#    'isPointer': False,
#    'description': 'geneID-64080',
#    'userAttributes': {}},
#   'geneID-64422': {'dtype': 'int64',
#    'modality': 'MOLECULE',
#    'isPointer': False,
#    'description': 'geneID-64422',
#    'userAttributes': {}},
#   'geneID-64428': {'dtype': 'int64',
#    'modality': 'MOLECULE',
#    'isPointer': False,
#    'description': 'geneID-64428',
#    'userAttributes': {}},
#   'geneID-64429': {'dtype': 'int64',
#    'modality': 'MOLECULE',
#    'isPointer': False,
#    'description': 'geneID-64429',
#    'userAttributes': {}},
#   'geneID-64746': {'dtype': 'int64',
#    'modality': 'MOLECULE',
#    'isPointer': False,
#    'description': 'geneID-64746',
#    'userAttributes': {}},
#   'geneID-64781': {'dtype': 'int64',
#    'modality': 'MOLECULE',
#    'isPointer': False,
#    'description': 'geneID-64781',
#    'userAttributes': {}},
#   'geneID-64943': {'dtype': 'int64',
#    'modality': 'MOLECULE',
#    'isPointer': False,
#    'description': 'geneID-64943',
#    'userAttributes': {}},
#   'geneID-65057': {'dtype': 'int64',
#    'modality': 'MOLECULE',
#    'isPointer': False,
#    'description': 'geneID-65057',
#    'userAttributes': {}},
#   'geneID-65123': {'dtype': 'int64',
#    'modality': 'MOLECULE',
#    'isPointer': False,
#    'description': 'geneID-65123',
#    'userAttributes': {}},
#   'geneID-66008': {'dtype': 'int64',
#    'modality': 'MOLECULE',
#    'isPointer': False,
#    'description': 'geneID-66008',
#    'userAttributes': {}},
#   'geneID-79006': {'dtype': 'int64',
#    'modality': 'MOLECULE',
#    'isPointer': False,
#    'description': 'geneID-79006',
#    'userAttributes': {}},
#   'geneID-79071': {'dtype': 'int64',
#    'modality': 'MOLECULE',
#    'isPointer': False,
#    'description': 'geneID-79071',
#    'userAttributes': {}},
#   'geneID-79073': {'dtype': 'int64',
#    'modality': 'MOLECULE',
#    'isPointer': False,
#    'description': 'geneID-79073',
#    'userAttributes': {}},
#   'geneID-79080': {'dtype': 'int64',
#    'modality': 'MOLECULE',
#    'isPointer': False,
#    'description': 'geneID-79080',
#    'userAttributes': {}},
#   'geneID-79090': {'dtype': 'int64',
#    'modality': 'MOLECULE',
#    'isPointer': False,
#    'description': 'geneID-79090',
#    'userAttributes': {}},
#   'geneID-79094': {'dtype': 'int64',
#    'modality': 'MOLECULE',
#    'isPointer': False,
#    'description': 'geneID-79094',
#    'userAttributes': {}},
#   'geneID-79143': {'dtype': 'int64',
#    'modality': 'MOLECULE',
#    'isPointer': False,
#    'description': 'geneID-79143',
#    'userAttributes': {}},
#   'geneID-79170': {'dtype': 'int64',
#    'modality': 'MOLECULE',
#    'isPointer': False,
#    'description': 'geneID-79170',
#    'userAttributes': {}},
#   'geneID-79174': {'dtype': 'int64',
#    'modality': 'MOLECULE',
#    'isPointer': False,
#    'description': 'geneID-79174',
#    'userAttributes': {}},
#   'geneID-79187': {'dtype': 'int64',
#    'modality': 'MOLECULE',
#    'isPointer': False,
#    'description': 'geneID-79187',
#    'userAttributes': {}},
#   'geneID-79600': {'dtype': 'int64',
#    'modality': 'MOLECULE',
#    'isPointer': False,
#    'description': 'geneID-79600',
#    'userAttributes': {}},
#   'geneID-79643': {'dtype': 'int64',
#    'modality': 'MOLECULE',
#    'isPointer': False,
#    'description': 'geneID-79643',
#    'userAttributes': {}},
#   'geneID-79716': {'dtype': 'int64',
#    'modality': 'MOLECULE',
#    'isPointer': False,
#    'description': 'geneID-79716',
#    'userAttributes': {}},
#   'geneID-79850': {'dtype': 'int64',
#    'modality': 'MOLECULE',
#    'isPointer': False,
#    'description': 'geneID-79850',
#    'userAttributes': {}},
#   'geneID-79902': {'dtype': 'int64',
#    'modality': 'MOLECULE',
#    'isPointer': False,
#    'description': 'geneID-79902',
#    'userAttributes': {}},
#   'geneID-79921': {'dtype': 'int64',
#    'modality': 'MOLECULE',
#    'isPointer': False,
#    'description': 'geneID-79921',
#    'userAttributes': {}},
#   'geneID-79947': {'dtype': 'int64',
#    'modality': 'MOLECULE',
#    'isPointer': False,
#    'description': 'geneID-79947',
#    'userAttributes': {}},
#   'geneID-79961': {'dtype': 'int64',
#    'modality': 'MOLECULE',
#    'isPointer': False,
#    'description': 'geneID-79961',
#    'userAttributes': {}},
#   'geneID-80204': {'dtype': 'int64',
#    'modality': 'MOLECULE',
#    'isPointer': False,
#    'description': 'geneID-80204',
#    'userAttributes': {}},
#   'geneID-80212': {'dtype': 'int64',
#    'modality': 'MOLECULE',
#    'isPointer': False,
#    'description': 'geneID-80212',
#    'userAttributes': {}},
#   'geneID-80347': {'dtype': 'int64',
#    'modality': 'MOLECULE',
#    'isPointer': False,
#    'description': 'geneID-80347',
#    'userAttributes': {}},
#   'geneID-80349': {'dtype': 'int64',
#    'modality': 'MOLECULE',
#    'isPointer': False,
#    'description': 'geneID-80349',
#    'userAttributes': {}},
#   'geneID-80746': {'dtype': 'int64',
#    'modality': 'MOLECULE',
#    'isPointer': False,
#    'description': 'geneID-80746',
#    'userAttributes': {}},
#   'geneID-80758': {'dtype': 'int64',
#    'modality': 'MOLECULE',
#    'isPointer': False,
#    'description': 'geneID-80758',
#    'userAttributes': {}},
#   'geneID-81533': {'dtype': 'int64',
#    'modality': 'MOLECULE',
#    'isPointer': False,
#    'description': 'geneID-81533',
#    'userAttributes': {}},
#   'geneID-81544': {'dtype': 'int64',
#    'modality': 'MOLECULE',
#    'isPointer': False,
#    'description': 'geneID-81544',
#    'userAttributes': {}},
#   'geneID-83743': {'dtype': 'int64',
#    'modality': 'MOLECULE',
#    'isPointer': False,
#    'description': 'geneID-83743',
#    'userAttributes': {}},
#   'geneID-84159': {'dtype': 'int64',
#    'modality': 'MOLECULE',
#    'isPointer': False,
#    'description': 'geneID-84159',
#    'userAttributes': {}},
#   'geneID-84617': {'dtype': 'int64',
#    'modality': 'MOLECULE',
#    'isPointer': False,
#    'description': 'geneID-84617',
#    'userAttributes': {}},
#   'geneID-84722': {'dtype': 'int64',
#    'modality': 'MOLECULE',
#    'isPointer': False,
#    'description': 'geneID-84722',
#    'userAttributes': {}},
#   'geneID-84890': {'dtype': 'int64',
#    'modality': 'MOLECULE',
#    'isPointer': False,
#    'description': 'geneID-84890',
#    'userAttributes': {}},
#   'geneID-85236': {'dtype': 'int64',
#    'modality': 'MOLECULE',
#    'isPointer': False,
#    'description': 'geneID-85236',
#    'userAttributes': {}},
#   'geneID-85377': {'dtype': 'int64',
#    'modality': 'MOLECULE',
#    'isPointer': False,
#    'description': 'geneID-85377',
#    'userAttributes': {}},
#   'geneID-89910': {'dtype': 'int64',
#    'modality': 'MOLECULE',
#    'isPointer': False,
#    'description': 'geneID-89910',
#    'userAttributes': {}},
#   'geneID-90861': {'dtype': 'int64',
#    'modality': 'MOLECULE',
#    'isPointer': False,
#    'description': 'geneID-90861',
#    'userAttributes': {}},
#   'geneID-91137': {'dtype': 'int64',
#    'modality': 'MOLECULE',
#    'isPointer': False,
#    'description': 'geneID-91137',
#    'userAttributes': {}},
#   'geneID-91949': {'dtype': 'int64',
#    'modality': 'MOLECULE',
#    'isPointer': False,
#    'description': 'geneID-91949',
#    'userAttributes': {}},
#   'geneID-93487': {'dtype': 'int64',
#    'modality': 'MOLECULE',
#    'isPointer': False,
#    'description': 'geneID-93487',
#    'userAttributes': {}},
#   'geneID-93594': {'dtype': 'int64',
#    'modality': 'MOLECULE',
#    'isPointer': False,
#    'description': 'geneID-93594',
#    'userAttributes': {}},
#   'geneID-94239': {'dtype': 'int64',
#    'modality': 'MOLECULE',
#    'isPointer': False,
#    'description': 'geneID-94239',
#    'userAttributes': {}},
#   'geneID-116832': {'dtype': 'int64',
#    'modality': 'MOLECULE',
#    'isPointer': False,
#    'description': 'geneID-116832',
#    'userAttributes': {}},
#   'geneID-124583': {'dtype': 'int64',
#    'modality': 'MOLECULE',
#    'isPointer': False,
#    'description': 'geneID-124583',
#    'userAttributes': {}},
#   'geneID-147179': {'dtype': 'int64',
#    'modality': 'MOLECULE',
#    'isPointer': False,
#    'description': 'geneID-147179',
#    'userAttributes': {}},
#   'geneID-148022': {'dtype': 'int64',
#    'modality': 'MOLECULE',
#    'isPointer': False,
#    'description': 'geneID-148022',
#    'userAttributes': {}},
#   'geneID-200081': {'dtype': 'int64',
#    'modality': 'MOLECULE',
#    'isPointer': False,
#    'description': 'geneID-200081',
#    'userAttributes': {}},
#   'geneID-200734': {'dtype': 'int64',
#    'modality': 'MOLECULE',
#    'isPointer': False,
#    'description': 'geneID-200734',
#    'userAttributes': {}},
#   'geneID-256364': {'dtype': 'int64',
#    'modality': 'MOLECULE',
#    'isPointer': False,
#    'description': 'geneID-256364',
#    'userAttributes': {}},
#   'geneID-375346': {'dtype': 'int64',
#    'modality': 'MOLECULE',
#    'isPointer': False,
#    'description': 'geneID-375346',
#    'userAttributes': {}},
#   'geneID-388650': {'dtype': 'int64',
#    'modality': 'MOLECULE',
#    'isPointer': False,
#    'description': 'geneID-388650',
#    'userAttributes': {}},
#   'compound_aliases': {'dtype': 'object',
#    'modality': 'UNKNOWN',
#    'isPointer': False,
#    'description': 'Molecule identifier',
#    'userAttributes': {}}},
#  'tableContent': {'url': 'https://polaris-nnd6pgwye-invivoai-platform.vercel.app/storage/dataset/graphium/l1000-mcf7-v1/table.parquet',
#   'size': 3153302,
#   'fileType': 'parquet'},
#  'defaultAdapters': {},
#  'zarrRootPath': None,
#  'zarrContent': {},
#  'artifactId': 'graphium/l1000-mcf7-v1',
#  'creator': {'slug': 'lu-valencelabs',
#   'externalId': 'user_2gtYwEALU6nz7YYhVOTrlJmkWtN',
#   'type': 'user'},
#  'owner': {'slug': 'graphium',
#   'externalId': 'org_2jLxcFOg0QSWqTheLPLjUp9AWys',
#   'type': 'organization'},
#  'benchmarks': [],
#  'review': None}
